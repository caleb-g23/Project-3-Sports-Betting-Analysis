# %%
# Dependencies
import requests
import csv
import json
import pandas as pd
from pathlib import Path

# %%
#read the csvs file into a data frame
team_state_data= Path('Resources/US_Team_Data.csv')
team_state_df= pd.read_csv(team_state_data)
team_state_df
# Out:
#                      Team                  Venue       City       state  \
# 0    Arizona Diamondbacks            Chase Field    Phoenix     Arizona
# 1            Phoenix Suns       Footprint Center    Phoenix     Arizona
# 2         Arizona Coyotes          Mullett Arena      Tempe     Arizona
# 3       Arizona Cardinals     State Farm Stadium   Glendale     Arizona
# 4      Los Angeles Angels          Angel Stadium    Anaheim  California
# ..                    ...                    ...        ...         ...
# 110      Seattle Seahawks            Lumen Field    Seattle  Washington
# 111      Seattle Mariners          T-Mobile Park    Seattle  Washington
# 112     Milwaukee Brewers  American Family Field  Milwaukee   Wisconsin
# 113       Milwaukee Bucks           Fiserv Forum  Milwaukee   Wisconsin
# 114     Green Bay Packers          Lambeau Field  Green Bay   Wisconsin
#
#     League       lat        lon
# 0      MLB   33.4453  -112.0669
# 1      NBA   33.4459  -112.0715
# ...

# %%
#Reorder the columns
order=['state', 'League', 'Team', 'City', 'Venue', 'lat', 'lon']
team_state_df=team_state_df[order]
team_state_df
# Out:
#           state League                  Team       City  \
# 0       Arizona    MLB  Arizona Diamondbacks    Phoenix
# 1       Arizona    NBA          Phoenix Suns    Phoenix
# 2       Arizona    NHL       Arizona Coyotes      Tempe
# 3       Arizona    NFL     Arizona Cardinals   Glendale
# 4    California    MLB    Los Angeles Angels    Anaheim
# ..          ...    ...                   ...        ...
# 110  Washington    NFL      Seattle Seahawks    Seattle
# 111  Washington    MLB      Seattle Mariners    Seattle
# 112   Wisconsin    MLB     Milwaukee Brewers  Milwaukee
# 113   Wisconsin    NBA       Milwaukee Bucks  Milwaukee
# 114   Wisconsin    NFL     Green Bay Packers  Green Bay
#
#                      Venue       lat        lon
# 0              Chase Field   33.4453  -112.0669
# 1         Footprint Center   33.4459  -112.0715
# 2            Mullett Arena   33.4267  -111.9286
# 3       State Farm Stadium   33.5277  -112.2626
# ...

# %%
team_state_df.to_csv('Resources/us_major_teams_FINAL.csv')

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            #primary key
            key = rows['']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))

# %%
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'Resources/us_major_teams_FINAL.csv'
jsonFilePath = r'json/US_Major_Teams.json'

# %%
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
